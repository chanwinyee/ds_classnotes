# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../data/titanic/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
df.SibSp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
df_sib = pd.get_dummies(df, columns=['SibSp'])
df_Sex = pd.get_dummies(df, columns=['Sex'])
df_Pclass = pd.get_dummies(df, columns=['Pclass'])

# %%
df_sib.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       Parch  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.381594
# std     257.353842    0.486592    0.836071   14.526497    0.806057
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    6.000000
#
#              Fare     SibSp_0     SibSp_1     SibSp_2     SibSp_3     SibSp_4  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    32.204208    0.682379    0.234568    0.031425    0.017957    0.020202
# std     49.693429    0.465813    0.423966    0.174562    0.132871    0.140770
# ...

# %%
df_Sex.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Sex_female    Sex_male
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.352413    0.647587
# std      0.806057   49.693429    0.477990    0.477990
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000    0.000000
# ...

# %%
df_Pclass.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    0.383838   29.699118    0.523008    0.381594
# std     257.353842    0.486592   14.526497    1.102743    0.806057
# min       1.000000    0.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000   20.125000    0.000000    0.000000
# 50%     446.000000    0.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare    Pclass_1    Pclass_2    Pclass_3
# count  891.000000  891.000000  891.000000  891.000000
# mean    32.204208    0.242424    0.206510    0.551066
# std     49.693429    0.428790    0.405028    0.497665
# min      0.000000    0.000000    0.000000    0.000000
# 25%      7.910400    0.000000    0.000000    0.000000
# ...

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='Pclass',y='Survived',data=df)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_sib.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     Parch      Fare  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481 -0.077221  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.189119  0.096067
# Parch          -0.001652  0.081629  0.018443 -0.189119  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  0.096067  0.216225  1.000000
# SibSp_0         0.053397 -0.115867  0.076009  0.162893 -0.356133 -0.192190
# SibSp_1        -0.013501  0.173076 -0.166435  0.015797  0.188220  0.133121
# SibSp_2        -0.023510  0.029796  0.010455 -0.092893  0.058416  0.070901
# SibSp_3        -0.065421 -0.037215  0.041082 -0.142148  0.156257  0.099936
# SibSp_4        -0.035946 -0.064123  0.118804 -0.250853  0.199346 -0.001008
# ...

# %%
sns.heatmap(df_sib.corr())

# %%
df_Sex.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Sex_female     -0.042939  0.543351 -0.131900 -0.093254  0.114631  0.245489
# Sex_male        0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
#
#                  Fare  Sex_female  Sex_male
# PassengerId  0.012658   -0.042939  0.042939
# Survived     0.257307    0.543351 -0.543351
# Pclass      -0.549500   -0.131900  0.131900
# ...

# %%
sns.heatmap(df_Sex.corr())

# %%
df_Pclass.corr()
# Out:
#              PassengerId  Survived       Age     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.005007  0.036847 -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.077221 -0.035322  0.081629  0.257307
# Age             0.036847 -0.077221  1.000000 -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.035322 -0.308247  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629 -0.189119  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307  0.096067  0.159651  0.216225  1.000000
# Pclass_1        0.034303  0.285904  0.348941 -0.054582 -0.017633  0.591711
# Pclass_2       -0.000086  0.093349  0.006954 -0.055932 -0.000734 -0.118557
# Pclass_3       -0.029486 -0.322308 -0.312271  0.092548  0.015790 -0.413333
#
#              Pclass_1  Pclass_2  Pclass_3
# PassengerId  0.034303 -0.000086 -0.029486
# Survived     0.285904  0.093349 -0.322308
# Age          0.348941  0.006954 -0.312271
# SibSp       -0.054582 -0.055932  0.092548
# ...

# %%
sns.heatmap(df_Pclass.corr())
